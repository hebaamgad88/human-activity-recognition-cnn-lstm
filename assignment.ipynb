# %% [markdown]
# #**Importing the Libraries**

# %%
import os
import cv2
import pafy
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# %%capture

# !wget --no-check-certificate https://www.crcv.ucf.edu/data/UCF50.rar
# !unrar x UCF50.rar

# %%
plt.figure(figsize = (20, 20))

all_classes_names = os.listdir('UCF50')


random_range = random.sample(range(len(all_classes_names)), 20)

for counter, random_index in enumerate(random_range, 1):

  selected_class_name = all_classes_names[random_index]

  video_files_names_list = os.listdir(f'UCF50/{selected_class_name}')

  selected_video_file_name = random.choice(video_files_names_list)

  video_reader = cv2.VideoCapture(f'UCF50/{selected_class_name}/{selected_video_file_name}')

  _, bgr_frame = video_reader.read()

  video_reader.release()

  rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

  cv2.putText(rgb_frame, selected_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)

  plt.subplot(5, 4, counter);
  plt.imshow(rgb_frame);
  plt.axis('off')

# %%
IMAGE_HEIGHT, IMAGE_WIDTH = 64, 64

SEQUENCE_LENGTH = 20

DATASET_DIR = "UCF50"

CLASSES_LIST = ["WalkingWithDog", "TaiChi", "Swing", "HorseRace"]

# %%
def frames_extraction(video_path):
  

  frames_list = []

  video_reader = cv2.VideoCapture(video_path)

  video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

  skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

  for frame_counter in range(SEQUENCE_LENGTH):

    video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

    success, frame = video_reader.read()

    if not success:
      break

    resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

    normalized_frame = resized_frame / 255

    frames_list.append(normalized_frame)

  video_reader.release()

  return frames_list

# %%
def create_dataset():
  
  features = []
  labels = []
  video_files_paths = []

  for class_index, class_name in enumerate(CLASSES_LIST):

    print(f'Extracting Data of Class: {class_name}')

    files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

    for file_name in files_list:

      video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

      frames = frames_extraction(video_file_path)


      if len(frames) == SEQUENCE_LENGTH:

        features.append(frames)
        labels.append(class_index)
        video_files_paths.append(video_file_path)

  features = np.asarray(features)
  labels = np.array(labels)

  return features, labels, video_files_paths

# %%
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: WalkingWithDog
# Extracting Data of Class: TaiChi
# Extracting Data of Class: Swing
# Extracting Data of Class: HorseRace

# %%
one_hot_encoded_labels = to_categorical(labels)

# %%
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)

# %%
def create_convlstm_model():
  
  model = Sequential()

  

  model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                        recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                         IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                        recurrent_dropout=0.2, return_sequences=True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                        recurrent_dropout=0.2, return_sequences=True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
  model.add(TimeDistributed(Dropout(0.2)))

  model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                        recurrent_dropout=0.2, return_sequences=True))

  model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))

  model.add(Flatten())
  model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

  model.summary()

  return model

# %%
convlstm_model = create_convlstm_model()
print("Model Created Successfully!")
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv_lstm2d_10 (ConvLSTM2D)          │ (None, 20, 62, 62, 4)       │           1,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_5 (MaxPooling3D)       │ (None, 20, 31, 31, 4)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_5 (TimeDistributed) │ (None, 20, 31, 31, 4)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_11 (ConvLSTM2D)          │ (None, 20, 29, 29, 8)       │           3,488 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_6 (MaxPooling3D)       │ (None, 20, 15, 15, 8)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_6 (TimeDistributed) │ (None, 20, 15, 15, 8)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_12 (ConvLSTM2D)          │ (None, 20, 13, 13, 14)      │          11,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_7 (MaxPooling3D)       │ (None, 20, 7, 7, 14)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_7 (TimeDistributed) │ (None, 20, 7, 7, 14)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv_lstm2d_13 (ConvLSTM2D)          │ (None, 20, 5, 5, 16)        │          17,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling3d_8 (MaxPooling3D)       │ (None, 20, 3, 3, 16)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 2880)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │          11,524 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 44,524 (173.92 KB)
#  Trainable params: 44,524 (173.92 KB)
#  Non-trainable params: 0 (0.00 B)
# Model Created Successfully!

# %%
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)

convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 4 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 125s 2s/step - accuracy: 0.2869 - loss: 1.3944 - val_accuracy: 0.4521 - val_loss: 1.3395
# Epoch 2/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.4233 - loss: 1.2962 - val_accuracy: 0.4521 - val_loss: 1.2766
# Epoch 3/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 137s 1s/step - accuracy: 0.5472 - loss: 1.1509 - val_accuracy: 0.5616 - val_loss: 1.1734
# Epoch 4/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 143s 1s/step - accuracy: 0.6232 - loss: 1.0098 - val_accuracy: 0.6164 - val_loss: 0.9460
# Epoch 5/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.6091 - loss: 0.9472 - val_accuracy: 0.6986 - val_loss: 0.8336
# Epoch 6/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.7213 - loss: 0.7568 - val_accuracy: 0.7671 - val_loss: 0.7490
# Epoch 7/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 138s 1s/step - accuracy: 0.7956 - loss: 0.5843 - val_accuracy: 0.7397 - val_loss: 0.8077
# Epoch 8/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 0.8256 - loss: 0.4738 - val_accuracy: 0.7397 - val_loss: 0.7952
# Epoch 9/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 105s 1s/step - accuracy: 0.8481 - loss: 0.3722 - val_accuracy: 0.6575 - val_loss: 1.1674
# Epoch 10/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 147s 2s/step - accuracy: 0.8676 - loss: 0.3050 - val_accuracy: 0.6986 - val_loss: 1.0456
# Epoch 11/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 142s 2s/step - accuracy: 0.8957 - loss: 0.2736 - val_accuracy: 0.7534 - val_loss: 0.9422
# Epoch 12/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 0.9059 - loss: 0.2467 - val_accuracy: 0.7260 - val_loss: 0.6341
# Epoch 13/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 106s 1s/step - accuracy: 0.9501 - loss: 0.1164 - val_accuracy: 0.7123 - val_loss: 0.7918
# Epoch 14/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9764 - loss: 0.0685 - val_accuracy: 0.7534 - val_loss: 0.7296
# Epoch 15/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9746 - loss: 0.0851 - val_accuracy: 0.7397 - val_loss: 0.9173
# Epoch 16/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9539 - loss: 0.1121 - val_accuracy: 0.6849 - val_loss: 1.0470
# Epoch 17/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.9449 - loss: 0.1370 - val_accuracy: 0.7945 - val_loss: 0.5705
# Epoch 18/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 109s 1s/step - accuracy: 0.9777 - loss: 0.0662 - val_accuracy: 0.7945 - val_loss: 0.7127
# Epoch 19/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 140s 1s/step - accuracy: 0.9922 - loss: 0.0264 - val_accuracy: 0.7671 - val_loss: 0.8862
# Epoch 20/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 139s 1s/step - accuracy: 1.0000 - loss: 0.0102 - val_accuracy: 0.7945 - val_loss: 0.7094
# Epoch 21/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 142s 1s/step - accuracy: 0.9996 - loss: 0.0117 - val_accuracy: 0.7671 - val_loss: 0.9586
# Epoch 22/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 147s 1s/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.7945 - val_loss: 0.7192
# Epoch 23/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 104s 1s/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.7671 - val_loss: 0.7637
# Epoch 24/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.7671 - val_loss: 0.7866
# Epoch 25/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7808 - val_loss: 0.8627
# Epoch 26/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 141s 1s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.7945 - val_loss: 0.8228
# Epoch 27/50
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 145s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.7945 - val_loss: 0.8060

# %%
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 13s 3s/step - accuracy: 0.8227 - loss: 0.6681

# %%
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

convlstm_model.save(model_file_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):


  metric_value_1 = model_training_history.history[metric_name_1]
  metric_value_2 = model_training_history.history[metric_name_2]

  epochs = range(len(metric_value_1))

  plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
  plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

  plt.title(str(plot_name))

  plt.legend()

# %%
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
def create_LRCN_model():

    model = Sequential()

    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))

    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(32))

    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    model.summary()

    return model

# %%
LRCN_model = create_LRCN_model()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ time_distributed_20                  │ (None, 20, 64, 64, 16)      │             448 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_21                  │ (None, 20, 16, 16, 16)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_22                  │ (None, 20, 16, 16, 16)      │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_23                  │ (None, 20, 16, 16, 32)      │           4,640 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_24                  │ (None, 20, 4, 4, 32)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_25                  │ (None, 20, 4, 4, 32)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_26                  │ (None, 20, 4, 4, 64)        │          18,496 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_27                  │ (None, 20, 2, 2, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_28                  │ (None, 20, 2, 2, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_29                  │ (None, 20, 2, 2, 64)        │          36,928 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_30                  │ (None, 20, 1, 1, 64)        │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ time_distributed_31                  │ (None, 20, 64)              │               0 │
# │ (TimeDistributed)                    │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 32)                  │          12,416 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 4)                   │             132 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 73,060 (285.39 KB)
#  Trainable params: 73,060 (285.39 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## **Checking Model's Struture**

# %%
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %%
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)

LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 , shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 58s 544ms/step - accuracy: 0.2684 - loss: 1.4166 - val_accuracy: 0.1781 - val_loss: 1.3849
# Epoch 2/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 496ms/step - accuracy: 0.3334 - loss: 1.3474 - val_accuracy: 0.4110 - val_loss: 1.2941
# Epoch 3/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 489ms/step - accuracy: 0.3903 - loss: 1.4076 - val_accuracy: 0.4932 - val_loss: 1.1850
# Epoch 4/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 43s 519ms/step - accuracy: 0.4104 - loss: 1.2755 - val_accuracy: 0.5479 - val_loss: 1.1283
# Epoch 5/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 508ms/step - accuracy: 0.5272 - loss: 1.1533 - val_accuracy: 0.4795 - val_loss: 1.2310
# Epoch 6/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - accuracy: 0.5145 - loss: 0.9950 - val_accuracy: 0.5342 - val_loss: 1.1112
# Epoch 7/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 39s 479ms/step - accuracy: 0.5848 - loss: 0.9004 - val_accuracy: 0.6301 - val_loss: 0.9027
# Epoch 8/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 484ms/step - accuracy: 0.6376 - loss: 0.9047 - val_accuracy: 0.6301 - val_loss: 0.8630
# Epoch 9/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 506ms/step - accuracy: 0.6919 - loss: 0.7303 - val_accuracy: 0.6575 - val_loss: 0.8042
# Epoch 10/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 513ms/step - accuracy: 0.7537 - loss: 0.6222 - val_accuracy: 0.7260 - val_loss: 0.6710
# Epoch 11/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 46s 578ms/step - accuracy: 0.7510 - loss: 0.6258 - val_accuracy: 0.5342 - val_loss: 1.2930
# Epoch 12/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 76s 497ms/step - accuracy: 0.7967 - loss: 0.5671 - val_accuracy: 0.7397 - val_loss: 0.6623
# Epoch 13/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 484ms/step - accuracy: 0.8121 - loss: 0.5187 - val_accuracy: 0.6164 - val_loss: 1.0241
# Epoch 14/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 505ms/step - accuracy: 0.8766 - loss: 0.3657 - val_accuracy: 0.8356 - val_loss: 0.5489
# Epoch 15/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 42s 519ms/step - accuracy: 0.9043 - loss: 0.3063 - val_accuracy: 0.8219 - val_loss: 0.5129
# Epoch 16/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 35s 482ms/step - accuracy: 0.9264 - loss: 0.2569 - val_accuracy: 0.8767 - val_loss: 0.4730
# Epoch 17/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 43s 515ms/step - accuracy: 0.9419 - loss: 0.2275 - val_accuracy: 0.8082 - val_loss: 0.7331
# Epoch 18/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 39s 487ms/step - accuracy: 0.9339 - loss: 0.2512 - val_accuracy: 0.7534 - val_loss: 0.6987
# Epoch 19/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 42s 503ms/step - accuracy: 0.8362 - loss: 0.4656 - val_accuracy: 0.6575 - val_loss: 0.9324
# Epoch 20/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 514ms/step - accuracy: 0.9134 - loss: 0.2635 - val_accuracy: 0.7671 - val_loss: 0.5731
# Epoch 21/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 521ms/step - accuracy: 0.9058 - loss: 0.2581 - val_accuracy: 0.8630 - val_loss: 0.4733
# Epoch 22/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 507ms/step - accuracy: 0.9831 - loss: 0.0972 - val_accuracy: 0.8767 - val_loss: 0.4865
# Epoch 23/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 493ms/step - accuracy: 0.9832 - loss: 0.0870 - val_accuracy: 0.8767 - val_loss: 0.4716
# Epoch 24/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 507ms/step - accuracy: 0.9735 - loss: 0.0862 - val_accuracy: 0.7808 - val_loss: 0.7646
# Epoch 25/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 494ms/step - accuracy: 0.9582 - loss: 0.1160 - val_accuracy: 0.8082 - val_loss: 0.6433
# Epoch 26/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 36s 494ms/step - accuracy: 0.9379 - loss: 0.2502 - val_accuracy: 0.7808 - val_loss: 0.6615
# Epoch 27/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 501ms/step - accuracy: 0.9339 - loss: 0.2529 - val_accuracy: 0.6986 - val_loss: 0.9556
# Epoch 28/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 507ms/step - accuracy: 0.8669 - loss: 0.3773 - val_accuracy: 0.8630 - val_loss: 0.3997
# Epoch 29/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 42s 520ms/step - accuracy: 0.9601 - loss: 0.1510 - val_accuracy: 0.8767 - val_loss: 0.3837
# Epoch 30/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 514ms/step - accuracy: 0.9830 - loss: 0.0828 - val_accuracy: 0.8493 - val_loss: 0.5958
# Epoch 31/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 498ms/step - accuracy: 0.9787 - loss: 0.0822 - val_accuracy: 0.8219 - val_loss: 0.6792
# Epoch 32/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 482ms/step - accuracy: 0.9616 - loss: 0.1166 - val_accuracy: 0.8219 - val_loss: 0.5720
# Epoch 33/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 488ms/step - accuracy: 0.9855 - loss: 0.0615 - val_accuracy: 0.9041 - val_loss: 0.3846
# Epoch 34/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 486ms/step - accuracy: 0.9849 - loss: 0.0652 - val_accuracy: 0.8630 - val_loss: 0.5296
# Epoch 35/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 493ms/step - accuracy: 0.9859 - loss: 0.0430 - val_accuracy: 0.9041 - val_loss: 0.5438
# Epoch 36/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 474ms/step - accuracy: 0.9881 - loss: 0.0393 - val_accuracy: 0.8493 - val_loss: 0.5602
# Epoch 37/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 481ms/step - accuracy: 0.9853 - loss: 0.0709 - val_accuracy: 0.8630 - val_loss: 0.5268
# Epoch 38/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 483ms/step - accuracy: 0.9848 - loss: 0.0679 - val_accuracy: 0.9178 - val_loss: 0.4667
# Epoch 39/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 514ms/step - accuracy: 0.8665 - loss: 0.3682 - val_accuracy: 0.8904 - val_loss: 0.4874
# Epoch 40/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 39s 491ms/step - accuracy: 0.9507 - loss: 0.1840 - val_accuracy: 0.8767 - val_loss: 0.4347
# Epoch 41/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 40s 483ms/step - accuracy: 0.9664 - loss: 0.0977 - val_accuracy: 0.8630 - val_loss: 0.4594
# Epoch 42/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 41s 485ms/step - accuracy: 0.9886 - loss: 0.0472 - val_accuracy: 0.8767 - val_loss: 0.5096
# Epoch 43/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 37s 512ms/step - accuracy: 0.9886 - loss: 0.0415 - val_accuracy: 0.8767 - val_loss: 0.5506
# Epoch 44/70
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 36s 488ms/step - accuracy: 0.9886 - loss: 0.0249 - val_accuracy: 0.8904 - val_loss: 0.5587

# %%
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 620ms/step - accuracy: 0.8949 - loss: 0.3637

# %%
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'


LRCN_model.save(model_file_name)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')
